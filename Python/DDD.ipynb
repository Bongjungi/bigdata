# %% [markdown]
# # 1.

# %%
from matplotlib import pyplot as plt
#주피터노트북이 실행되는 브라우저에서 시각화를 해라...
# %matplotlib inline
#그래프 해상도를 높임. 'png'(기본값),'jpge','svg','pdf'
# %config InlineBackend.figure_format = 'retina'
import warnings
warnings.filterwarnings(action='ignore')
import numpy as np
#한글 기본폰트 설정
plt.rc('font', family='Malgun Gothic') # 윈도우즈
plt.rc('axes', unicode_minus=False) #축
#원하는 한글 폰트 지정
import matplotlib.font_manager as fm
font_path = 'C:\Windows\Fonts\HMFMPYUN.TTF'
font_prop = fm.FontProperties(fname=font_path, size=20)
import seaborn as sns
import pandas as pd

# %%
plt.plot([range(0,6)],[range(0,6)],'r+')
plt.title('시험용')
plt.text(0,1,'텍스트')
plt.show()

# %% [markdown]
# # 2.

# %%
df1=pd.read_csv('D:\Bigdata\download\sharedBigdata\소상공인시장진흥공단_상가(상권)정보_서울_202106.csv')
df2=pd.read_csv('D:\Bigdata\download\sharedBigdata\소상공인시장진흥공단_상가(상권)정보_부산_202106.csv')

# %%
df1
# Out:
#           상가업소번호      상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드      상권업종중분류명  \
# 0       17174175      비지트  NaN         Q       음식       Q01            한식
# 1       17174119     쓰리에프  NaN         Q       음식       Q01            한식
# 2       17174096       채움  NaN         Q       음식       Q01            한식
# 3       17174062    호구의주방  NaN         D       소매       D07    가정/주방/인테리어
# 4       17174040       다향  NaN         Q       음식       Q01            한식
# ...          ...      ...  ...       ...      ...       ...           ...
# 316073  16982165    김씨네주방  NaN         Q       음식       Q01            한식
# 316074  16980995    핫플레이스  NaN         Q       음식       Q01            한식
# 316075  20861429    경인철형사  NaN         D       소매       D21  철물/난방/건설자재소매
# 316076  16991493   솔시카고피자  NaN         Q       음식       Q07         패스트푸드
# 316077  16990345  피자버거플러스  NaN         Q       음식       Q07         패스트푸드
#
#        상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0         Q01A01  한식/백반/한정식   I56111  ...  1165010100108540018009586
# 1         Q01A01  한식/백반/한정식   I56111  ...  1159010700101390073009536
# 2         Q01A01  한식/백반/한정식   I56111  ...  1111012400100580000017956
# 3         D07A17     주방가구판매   G47520  ...  1156012800101600002019768
# 4         Q01A01  한식/백반/한정식   I56111  ...  1165010800114850004022127
# ...          ...        ...      ...  ...                        ...
# 316073    Q01A01  한식/백반/한정식   I56111  ...  1141011800104560000009675
# 316074    Q01A01  한식/백반/한정식   I56111  ...  1144012400105150024000001
# 316075    D21A06  철물/건설자재소매   G47511  ...  1174010800104200046004004
# 316076    Q07A01       피자전문   I56192  ...  1159010900107190000000001
# 316077    Q07A01       피자전문   I56192  ...  1117013600100810002002594
#
#              건물명                  도로명주소   구우편번호   신우편번호  동정보  층정보  호정보  \
# 0          상랑의빌딩    서울특별시 서초구 동광로18길 82  137837  6572.0  NaN    1  NaN
# 1            NaN  서울특별시 동작구 동작대로27가길 12  156816  7008.0  NaN  NaN  NaN
# 2       두산위브파빌리온       서울특별시 종로구 삼봉로 81  110858  3150.0  NaN  NaN  NaN
# 3        약산상가아파트     서울특별시 영등포구 선유로 269  150867  7206.0  NaN  NaN  NaN
# 4            NaN      서울특별시 서초구 효령로 230  137869  6709.0  NaN    1  NaN
# ...          ...                    ...     ...     ...  ...  ...  ...
# 316073     두산아파트    서울특별시 서대문구 모래내로 309  120775  3657.0  NaN  NaN  NaN
# 316074       NaN       서울특별시 마포구 연남로 29  121869  3988.0  NaN    1  NaN
# 316075       NaN       서울특별시 강동구 성안로 70  134030  5403.0  NaN    1  NaN
# 316076  동작상떼빌아파트    서울특별시 동작구 신대방1가길 38  156759  7072.0  NaN  NaN  NaN
# 316077       NaN       서울특별시 용산구 보광로 15  140823  4396.0  NaN    1  NaN
#
#                 경도         위도
# 0       126.991394  37.488375
# 1       126.980952  37.487105
# 2       126.981794  37.572387
# 3       126.897892  37.536700
# 4       127.009382  37.483436
# ...            ...        ...
# 316073  126.931473  37.578889
# 316074  126.921671  37.562230
# 316075  127.131765  37.529776
# 316076  126.906921  37.487893
# 316077  127.000969  37.525913
#
# [316078 rows x 39 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316078 entries, 0 to 316077
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     316078 non-null  int64
#  1   상호명        316077 non-null  object
#  2   지점명        54615 non-null   object
#  3   상권업종대분류코드  316078 non-null  object
#  4   상권업종대분류명   316078 non-null  object
#  5   상권업종중분류코드  316078 non-null  object
#  6   상권업종중분류명   316078 non-null  object
#  7   상권업종소분류코드  316078 non-null  object
#  8   상권업종소분류명   316078 non-null  object
#  9   표준산업분류코드   286026 non-null  object
#  10  표준산업분류명    286026 non-null  object
#  11  시도코드       316078 non-null  int64
#  12  시도명        316078 non-null  object
#  13  시군구코드      316078 non-null  int64
#  14  시군구명       316078 non-null  object
#  15  행정동코드      316078 non-null  int64
#  16  행정동명       315898 non-null  object
#  17  법정동코드      316078 non-null  int64
#  18  법정동명       316078 non-null  object
#  19  지번코드       316078 non-null  int64
#  20  대지구분코드     316078 non-null  int64
#  21  대지구분명      316078 non-null  object
#  22  지번본번지      316078 non-null  int64
#  23  지번부번지      254306 non-null  float64
#  24  지번주소       316078 non-null  object
#  25  도로명코드      316078 non-null  int64
#  26  도로명        316078 non-null  object
#  27  건물본번지      316078 non-null  int64
#  28  건물부번지      39460 non-null   float64
#  29  건물관리번호     316078 non-null  object
#  30  건물명        149818 non-null  object
#  31  도로명주소      316078 non-null  object
#  32  구우편번호      316078 non-null  int64
#  33  신우편번호      316075 non-null  float64
#  34  동정보        24605 non-null   object
#  35  층정보        200245 non-null  object
#  36  호정보        0 non-null       float64
#  37  경도         316078 non-null  float64
#  38  위도         316078 non-null  float64
# dtypes: float64(6), int64(11), object(22)
# memory usage: 94.0+ MB

# %%
df2
# Out:
#           상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드      상권업종중분류명  \
# 0       17174094      도란도란  NaN         Q       음식       Q01            한식
# 1       23206623       미광장  NaN         O       숙박       O02     모텔/여관/여인숙
# 2       20418637     BHC치킨  동래점         Q       음식       Q05        닭/오리요리
# 3       24659633       스텔라  NaN         D       소매       D05          의복의류
# 4       17175332      정성밥상  NaN         Q       음식       Q01            한식
# ...          ...       ...  ...       ...      ...       ...           ...
# 136512  21613939     일광카메라  NaN         D       소매       D18  사진/광학/정밀기기소매
# 136513  20026231     파워씨마트  NaN         D       소매       D03         종합소매점
# 136514  16993458  철마청년협동조합  NaN         Q       음식       Q01            한식
# 136515  16993416      소금주방  NaN         Q       음식       Q01            한식
# 136516  16982219       에이유  NaN         Q       음식       Q01            한식
#
#        상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0         Q01A01  한식/백반/한정식   I56111  ...  2623011100101740004050547
# 1         O02A01  모텔/여관/여인숙   I55112  ...  2611012600100250001004473
# 2         Q05A08  후라이드/양념치킨   I56193  ...  2626010500101850000016529
# 3         D05A01       일반의류   G47416  ...  2650010500101480004001694
# 4         Q01A01  한식/백반/한정식   I56111  ...  2635010500105520002023290
# ...          ...        ...      ...  ...                        ...
# 136512    D18A03      카메라판매   G47823  ...  2611013300100170004007530
# 136513    D03A02       수퍼마켓   G47121  ...  2632010500112090001012804
# 136514    Q01A01  한식/백반/한정식   I56111  ...  2635010500114680000000001
# 136515    Q01A01  한식/백반/한정식   I56111  ...  2650010300101460027018793
# 136516    Q01A01  한식/백반/한정식   I56111  ...  2644010400134120001000001
#
#               건물명                      도로명주소   구우편번호    신우편번호  동정보  층정보  호정보  \
# 0             NaN  부산광역시 부산진구 가야대로482번길 29-3  614813  47327.0  NaN  NaN  NaN
# 1             NaN        부산광역시 중구 보수대로44번길 5  600074  48974.0  NaN  NaN  NaN
# 2             NaN      부산광역시 동래구 동래로147번길 18  607020  47802.0  NaN  NaN  NaN
# 3           비치아파트        부산광역시 수영구 광안해변로 100  613751  48305.0  NaN  NaN  NaN
# 4             NaN      부산광역시 해운대구 해운대로 635-7  612819  48087.0  NaN  NaN  NaN
# ...           ...                        ...     ...      ...  ...  ...  ...
# 136512        NaN            부산광역시 중구 광복로 85  600031  48952.0  NaN  NaN  NaN
# 136513        NaN           부산광역시 북구 모분재로 43  616090  46619.0  NaN  NaN  NaN
# 136514  케이엔엔월석아트홀         부산광역시 해운대구 센텀서로 20  612022  48058.0  NaN  NaN  NaN
# 136515        NaN     부산광역시 수영구 무학로63번길 45-6  613829  48273.0  NaN  NaN  NaN
# 136516        NaN       부산광역시 강서구 명지국제8로 230  618200  46726.0  NaN  NaN  NaN
#
#                 경도         위도
# 0       129.024938  35.151645
# 1       129.023668  35.100979
# 2       129.087156  35.205267
# 3       129.115397  35.143770
# 4       129.159641  35.164474
# ...            ...        ...
# 136512  129.034179  35.098690
# 136513  129.005835  35.203689
# 136514  129.129001  35.171335
# 136515  129.119690  35.163209
# 136516  128.917833  35.097932
#
# [136517 rows x 39 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136517 entries, 0 to 136516
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     136517 non-null  int64
#  1   상호명        136516 non-null  object
#  2   지점명        18836 non-null   object
#  3   상권업종대분류코드  136517 non-null  object
#  4   상권업종대분류명   136517 non-null  object
#  5   상권업종중분류코드  136517 non-null  object
#  6   상권업종중분류명   136517 non-null  object
#  7   상권업종소분류코드  136517 non-null  object
#  8   상권업종소분류명   136517 non-null  object
#  9   표준산업분류코드   123662 non-null  object
#  10  표준산업분류명    123662 non-null  object
#  11  시도코드       136517 non-null  int64
#  12  시도명        136517 non-null  object
#  13  시군구코드      136517 non-null  int64
#  14  시군구명       136517 non-null  object
#  15  행정동코드      136517 non-null  int64
#  16  행정동명       136284 non-null  object
#  17  법정동코드      136517 non-null  int64
#  18  법정동명       136517 non-null  object
#  19  지번코드       136517 non-null  int64
#  20  대지구분코드     136517 non-null  int64
#  21  대지구분명      136517 non-null  object
#  22  지번본번지      136517 non-null  int64
#  23  지번부번지      116948 non-null  float64
#  24  지번주소       136517 non-null  object
#  25  도로명코드      136517 non-null  int64
#  26  도로명        136517 non-null  object
#  27  건물본번지      136517 non-null  int64
#  28  건물부번지      20166 non-null   float64
#  29  건물관리번호     136517 non-null  object
#  30  건물명        54802 non-null   object
#  31  도로명주소      136517 non-null  object
#  32  구우편번호      136517 non-null  int64
#  33  신우편번호      136509 non-null  float64
#  34  동정보        15391 non-null   object
#  35  층정보        57163 non-null   object
#  36  호정보        0 non-null       float64
#  37  경도         136517 non-null  float64
#  38  위도         136517 non-null  float64
# dtypes: float64(6), int64(11), object(22)
# memory usage: 40.6+ MB

# %%
df=pd.concat([df1,df2])
df
# Out:
#           상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드      상권업종중분류명  \
# 0       17174175       비지트  NaN         Q       음식       Q01            한식
# 1       17174119      쓰리에프  NaN         Q       음식       Q01            한식
# 2       17174096        채움  NaN         Q       음식       Q01            한식
# 3       17174062     호구의주방  NaN         D       소매       D07    가정/주방/인테리어
# 4       17174040        다향  NaN         Q       음식       Q01            한식
# ...          ...       ...  ...       ...      ...       ...           ...
# 136512  21613939     일광카메라  NaN         D       소매       D18  사진/광학/정밀기기소매
# 136513  20026231     파워씨마트  NaN         D       소매       D03         종합소매점
# 136514  16993458  철마청년협동조합  NaN         Q       음식       Q01            한식
# 136515  16993416      소금주방  NaN         Q       음식       Q01            한식
# 136516  16982219       에이유  NaN         Q       음식       Q01            한식
#
#        상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0         Q01A01  한식/백반/한정식   I56111  ...  1165010100108540018009586
# 1         Q01A01  한식/백반/한정식   I56111  ...  1159010700101390073009536
# 2         Q01A01  한식/백반/한정식   I56111  ...  1111012400100580000017956
# 3         D07A17     주방가구판매   G47520  ...  1156012800101600002019768
# 4         Q01A01  한식/백반/한정식   I56111  ...  1165010800114850004022127
# ...          ...        ...      ...  ...                        ...
# 136512    D18A03      카메라판매   G47823  ...  2611013300100170004007530
# 136513    D03A02       수퍼마켓   G47121  ...  2632010500112090001012804
# 136514    Q01A01  한식/백반/한정식   I56111  ...  2635010500114680000000001
# 136515    Q01A01  한식/백반/한정식   I56111  ...  2650010300101460027018793
# 136516    Q01A01  한식/백반/한정식   I56111  ...  2644010400134120001000001
#
#               건물명                   도로명주소   구우편번호    신우편번호  동정보  층정보  호정보  \
# 0           상랑의빌딩     서울특별시 서초구 동광로18길 82  137837   6572.0  NaN    1  NaN
# 1             NaN   서울특별시 동작구 동작대로27가길 12  156816   7008.0  NaN  NaN  NaN
# 2        두산위브파빌리온        서울특별시 종로구 삼봉로 81  110858   3150.0  NaN  NaN  NaN
# 3         약산상가아파트      서울특별시 영등포구 선유로 269  150867   7206.0  NaN  NaN  NaN
# 4             NaN       서울특별시 서초구 효령로 230  137869   6709.0  NaN    1  NaN
# ...           ...                     ...     ...      ...  ...  ...  ...
# 136512        NaN         부산광역시 중구 광복로 85  600031  48952.0  NaN  NaN  NaN
# 136513        NaN        부산광역시 북구 모분재로 43  616090  46619.0  NaN  NaN  NaN
# 136514  케이엔엔월석아트홀      부산광역시 해운대구 센텀서로 20  612022  48058.0  NaN  NaN  NaN
# 136515        NaN  부산광역시 수영구 무학로63번길 45-6  613829  48273.0  NaN  NaN  NaN
# 136516        NaN    부산광역시 강서구 명지국제8로 230  618200  46726.0  NaN  NaN  NaN
#
#                 경도         위도
# 0       126.991394  37.488375
# 1       126.980952  37.487105
# 2       126.981794  37.572387
# 3       126.897892  37.536700
# 4       127.009382  37.483436
# ...            ...        ...
# 136512  129.034179  35.098690
# 136513  129.005835  35.203689
# 136514  129.129001  35.171335
# 136515  129.119690  35.163209
# 136516  128.917833  35.097932
#
# [452595 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 452595 entries, 0 to 136516
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     452595 non-null  int64
#  1   상호명        452593 non-null  object
#  2   지점명        73451 non-null   object
#  3   상권업종대분류코드  452595 non-null  object
#  4   상권업종대분류명   452595 non-null  object
#  5   상권업종중분류코드  452595 non-null  object
#  6   상권업종중분류명   452595 non-null  object
#  7   상권업종소분류코드  452595 non-null  object
#  8   상권업종소분류명   452595 non-null  object
#  9   표준산업분류코드   409688 non-null  object
#  10  표준산업분류명    409688 non-null  object
#  11  시도코드       452595 non-null  int64
#  12  시도명        452595 non-null  object
#  13  시군구코드      452595 non-null  int64
#  14  시군구명       452595 non-null  object
#  15  행정동코드      452595 non-null  int64
#  16  행정동명       452182 non-null  object
#  17  법정동코드      452595 non-null  int64
#  18  법정동명       452595 non-null  object
#  19  지번코드       452595 non-null  int64
#  20  대지구분코드     452595 non-null  int64
#  21  대지구분명      452595 non-null  object
#  22  지번본번지      452595 non-null  int64
#  23  지번부번지      371254 non-null  float64
#  24  지번주소       452595 non-null  object
#  25  도로명코드      452595 non-null  int64
#  26  도로명        452595 non-null  object
#  27  건물본번지      452595 non-null  int64
#  28  건물부번지      59626 non-null   float64
#  29  건물관리번호     452595 non-null  object
#  30  건물명        204620 non-null  object
#  31  도로명주소      452595 non-null  object
#  32  구우편번호      452595 non-null  int64
#  33  신우편번호      452584 non-null  float64
#  34  동정보        39996 non-null   object
#  35  층정보        257408 non-null  object
#  36  호정보        0 non-null       float64
#  37  경도         452595 non-null  float64
#  38  위도         452595 non-null  float64
# dtypes: float64(6), int64(11), object(22)
# memory usage: 138.1+ MB

# %%
df.index = range(df.shape[0])

# %% [markdown]
# # 3.

# %% [markdown]
# ## 1)

# %%
df.isna().sum().sort_values(ascending=False).reset_index().iloc[[0,1,2,-3,-2,-1]]
# Out:
#         index       0
# 0         호정보  452595
# 1         동정보  412599
# 2       건물부번지  392969
# 36   상권업종대분류명       0
# 37  상권업종대분류코드       0
# 38         위도       0

# %% [markdown]
# ## 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452595 entries, 0 to 452594
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     452595 non-null  int64
#  1   상호명        452593 non-null  object
#  2   지점명        73451 non-null   object
#  3   상권업종대분류코드  452595 non-null  object
#  4   상권업종대분류명   452595 non-null  object
#  5   상권업종중분류코드  452595 non-null  object
#  6   상권업종중분류명   452595 non-null  object
#  7   상권업종소분류코드  452595 non-null  object
#  8   상권업종소분류명   452595 non-null  object
#  9   표준산업분류코드   409688 non-null  object
#  10  표준산업분류명    409688 non-null  object
#  11  시도코드       452595 non-null  int64
#  12  시도명        452595 non-null  object
#  13  시군구코드      452595 non-null  int64
#  14  시군구명       452595 non-null  object
#  15  행정동코드      452595 non-null  int64
#  16  행정동명       452182 non-null  object
#  17  법정동코드      452595 non-null  int64
#  18  법정동명       452595 non-null  object
#  19  지번코드       452595 non-null  int64
#  20  대지구분코드     452595 non-null  int64
#  21  대지구분명      452595 non-null  object
#  22  지번본번지      452595 non-null  int64
#  23  지번부번지      371254 non-null  float64
#  24  지번주소       452595 non-null  object
#  25  도로명코드      452595 non-null  int64
#  26  도로명        452595 non-null  object
#  27  건물본번지      452595 non-null  int64
#  28  건물부번지      59626 non-null   float64
#  29  건물관리번호     452595 non-null  object
#  30  건물명        204620 non-null  object
#  31  도로명주소      452595 non-null  object
#  32  구우편번호      452595 non-null  int64
#  33  신우편번호      452584 non-null  float64
#  34  동정보        39996 non-null   object
#  35  층정보        257408 non-null  object
#  36  호정보        0 non-null       float64
#  37  경도         452595 non-null  float64
#  38  위도         452595 non-null  float64
# dtypes: float64(6), int64(11), object(22)
# memory usage: 134.7+ MB

# %% [markdown]
# ## 3)

# %%
df.isna().sum()
# Out:
# 상가업소번호            0
# 상호명               2
# 지점명          379144
# 상권업종대분류코드         0
# 상권업종대분류명          0
# 상권업종중분류코드         0
# 상권업종중분류명          0
# 상권업종소분류코드         0
# 상권업종소분류명          0
# 표준산업분류코드      42907
# 표준산업분류명       42907
# 시도코드              0
# 시도명               0
# 시군구코드             0
# 시군구명              0
# 행정동코드             0
# 행정동명            413
# 법정동코드             0
# 법정동명              0
# 지번코드              0
# 대지구분코드            0
# 대지구분명             0
# 지번본번지             0
# 지번부번지         81341
# 지번주소              0
# 도로명코드             0
# 도로명               0
# 건물본번지             0
# 건물부번지        392969
# 건물관리번호            0
# 건물명          247975
# 도로명주소             0
# 구우편번호             0
# 신우편번호            11
# 동정보          412599
# 층정보          195187
# 호정보          452595
# 경도                0
# 위도                0
# dtype: int64

# %%
a=df.isna().sum().reset_index()
a.columns=['ind','value']

# %%
for i,j in enumerate(a.ind):
    print(i,j)
# Out:
# 0 상가업소번호
# 1 상호명
# 2 지점명
# 3 상권업종대분류코드
# 4 상권업종대분류명
# 5 상권업종중분류코드
# 6 상권업종중분류명
# 7 상권업종소분류코드
# 8 상권업종소분류명
# 9 표준산업분류코드
# 10 표준산업분류명
# 11 시도코드
# 12 시도명
# 13 시군구코드
# 14 시군구명
# 15 행정동코드
# 16 행정동명
# 17 법정동코드
# 18 법정동명
# 19 지번코드
# 20 대지구분코드
# 21 대지구분명
# 22 지번본번지
# 23 지번부번지
# 24 지번주소
# 25 도로명코드
# 26 도로명
# 27 건물본번지
# 28 건물부번지
# 29 건물관리번호
# 30 건물명
# 31 도로명주소
# 32 구우편번호
# 33 신우편번호
# 34 동정보
# 35 층정보
# 36 호정보
# 37 경도
# 38 위도

# %%
plt.figure(figsize=(20,10))
plt.bar(data=a, x=a.ind, height=a.value)
for i, j in enumerate(a.ind):
    plt.text(j, a.value[i], a.value[i],horizontalalignment='center',va='bottom')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.barh(data=a, y=a.ind, width=a.value)
for i, j in enumerate(a.ind):
    plt.text(a.value[i], j, a.value[i],horizontalalignment='left',va='center')
plt.show()

# %%
a=df.isna().sum().sort_values(ascending=False).reset_index()
a.columns=['ind','value']

# %%
plt.figure(figsize=(20,10))
plt.bar(data=a, x=a.ind, height=a.value)
for i, j in enumerate(a.ind):
    plt.text(j, a.value[i], a.value[i],horizontalalignment='center',va='bottom')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.barh(data=a, y=a.ind, width=a.value)
for i, j in enumerate(a.ind):
    plt.text(a.value[i], j, a.value[i],horizontalalignment='left',va='center')
plt.show()

# %% [markdown]
# ## 4)

# %%
a=df.isna().sum()[df.isna().sum()!=0].reset_index()
a.columns=['ind','value']

# %%
plt.figure(figsize=(20,10))
plt.bar(data=a, x=a.ind, height=a.value)
for i, j in enumerate(a.ind):
    plt.text(j, a.value[i], a.value[i],horizontalalignment='center',va='bottom')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.barh(data=a, y=a.ind, width=a.value)
for i, j in enumerate(a.ind):
    plt.text(a.value[i], j, a.value[i],horizontalalignment='left',va='center')
plt.show()

# %%
a=df.isna().sum()[df.isna().sum()!=0].sort_values().reset_index()
a.columns=['ind','value']

# %%
plt.figure(figsize=(20,10))
plt.bar(data=a, x=a.ind, height=a.value)
for i, j in enumerate(a.ind):
    plt.text(j, a.value[i], a.value[i],horizontalalignment='center',va='bottom')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.barh(data=a, y=a.ind, width=a.value)
for i, j in enumerate(a.ind):
    plt.text(a.value[i], j, a.value[i],horizontalalignment='left',va='center')
plt.show()

# %% [markdown]
# # 4.

# %% [markdown]
# ## 1)

# %%
a=df.isna().sum().sort_values(ascending=False)[0:9]

# %%
df=df.drop(labels=df.isna().sum().sort_values(ascending=False)[0:9].index, axis=1)

# %% [markdown]
# ## 2)

# %%
condition=(df.columns.str.find('코드')!=-1)|(df.columns.str.find('번호')!=-1)

# %%
df=df.drop(labels=df.columns[condition], axis=1)

# %% [markdown]
# ## 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452595 entries, 0 to 452594
# Data columns (total 16 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   상호명       452593 non-null  object
#  1   상권업종대분류명  452595 non-null  object
#  2   상권업종중분류명  452595 non-null  object
#  3   상권업종소분류명  452595 non-null  object
#  4   시도명       452595 non-null  object
#  5   시군구명      452595 non-null  object
#  6   행정동명      452182 non-null  object
#  7   법정동명      452595 non-null  object
#  8   대지구분명     452595 non-null  object
#  9   지번본번지     452595 non-null  int64
#  10  지번주소      452595 non-null  object
#  11  도로명       452595 non-null  object
#  12  건물본번지     452595 non-null  int64
#  13  도로명주소     452595 non-null  object
#  14  경도        452595 non-null  float64
#  15  위도        452595 non-null  float64
# dtypes: float64(2), int64(2), object(12)
# memory usage: 55.2+ MB

# %% [markdown]
# # 5.

# %% [markdown]
# ## 1)

# %%
df['상호명']
# Out:
# 0              비지트
# 1             쓰리에프
# 2               채움
# 3            호구의주방
# 4               다향
#             ...
# 452590       일광카메라
# 452591       파워씨마트
# 452592    철마청년협동조합
# 452593        소금주방
# 452594         에이유
# Name: 상호명, Length: 452595, dtype: object

# %% [markdown]
# ## 2)

# %%
df.상호명.value_counts()
# Out:
# CU            2357
# GS25          1848
# 세븐일레븐         1259
# 카페             862
# 이마트            607
#               ...
# 파티호프             1
# 의창셔츠             1
# 호아구해물찜&탕         1
# 스튜디오마치스          1
# 최강떡볶이,최강삼겹       1
# Name: 상호명, Length: 309639, dtype: int64

# %% [markdown]
# ## 3)

# %%
df.loc[:,['상호명','도로명주소']]
# Out:
#              상호명                   도로명주소
# 0            비지트     서울특별시 서초구 동광로18길 82
# 1           쓰리에프   서울특별시 동작구 동작대로27가길 12
# 2             채움        서울특별시 종로구 삼봉로 81
# 3          호구의주방      서울특별시 영등포구 선유로 269
# 4             다향       서울특별시 서초구 효령로 230
# ...          ...                     ...
# 452590     일광카메라         부산광역시 중구 광복로 85
# 452591     파워씨마트        부산광역시 북구 모분재로 43
# 452592  철마청년협동조합      부산광역시 해운대구 센텀서로 20
# 452593      소금주방  부산광역시 수영구 무학로63번길 45-6
# 452594       에이유    부산광역시 강서구 명지국제8로 230
#
# [452595 rows x 2 columns]

# %% [markdown]
# ## 4)

# %%
df.iloc[0:3]
# Out:
#     상호명 상권업종대분류명 상권업종중분류명   상권업종소분류명    시도명 시군구명         행정동명 법정동명 대지구분명  \
# 0   비지트       음식       한식  한식/백반/한정식  서울특별시  서초구         방배4동  방배동    대지
# 1  쓰리에프       음식       한식  한식/백반/한정식  서울특별시  동작구         사당2동  사당동    대지
# 2    채움       음식       한식  한식/백반/한정식  서울특별시  종로구  종로1.2.3.4가동  수송동    대지
#
#    지번본번지                  지번주소                 도로명  건물본번지  \
# 0    854  서울특별시 서초구 방배동 854-18    서울특별시 서초구 동광로18길     82
# 1    139  서울특별시 동작구 사당동 139-72  서울특별시 동작구 동작대로27가길     12
# 2     58      서울특별시 종로구 수송동 58       서울특별시 종로구 삼봉로     81
#
#                    도로명주소          경도         위도
# 0    서울특별시 서초구 동광로18길 82  126.991394  37.488375
# 1  서울특별시 동작구 동작대로27가길 12  126.980952  37.487105
# 2       서울특별시 종로구 삼봉로 81  126.981794  37.572387

# %% [markdown]
# # 6.

# %% [markdown]
# ## 1)

# %%
df.describe()
# Out:
#                지번본번지          건물본번지             경도             위도
# count  452595.000000  452595.000000  452595.000000  452595.000000
# mean      480.054422     143.559566     127.618627      36.826891
# std       508.677492     264.580236       0.953961       1.093455
# min         1.000000       0.000000     126.768169      35.006760
# 25%       116.000000      19.000000     126.960323      35.211022
# 50%       336.000000      47.000000     127.048516      37.508608
# 75%       682.000000     151.000000     128.996827      37.560396
# max      9999.000000    3318.000000     129.292243      37.690787

# %% [markdown]
# ## 2)

# %%
df.지번본번지.to_frame().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452595 entries, 0 to 452594
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   지번본번지   452595 non-null  int64
# dtypes: int64(1)
# memory usage: 3.5 MB

# %%
df.건물본번지.to_frame().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452595 entries, 0 to 452594
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   건물본번지   452595 non-null  int64
# dtypes: int64(1)
# memory usage: 3.5 MB

# %%
df.loc[:,['지번본번지','건물본번지']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452595 entries, 0 to 452594
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   지번본번지   452595 non-null  int64
#  1   건물본번지   452595 non-null  int64
# dtypes: int64(2)
# memory usage: 6.9 MB

# %%
df.loc[:,['위도','경도']].describe()
# Out:
#                   위도             경도
# count  452595.000000  452595.000000
# mean       36.826891     127.618627
# std         1.093455       0.953961
# min        35.006760     126.768169
# 25%        35.211022     126.960323
# 50%        37.508608     127.048516
# 75%        37.560396     128.996827
# max        37.690787     129.292243

# %%
df['위도']
# Out:
# 0         37.488375
# 1         37.487105
# 2         37.572387
# 3         37.536700
# 4         37.483436
#             ...
# 452590    35.098690
# 452591    35.203689
# 452592    35.171335
# 452593    35.163209
# 452594    35.097932
# Name: 위도, Length: 452595, dtype: float64

# %% [markdown]
# # 7.

# %% [markdown]
# ## 1)

# %%
plt.figure(figsize=(20,10))
g = plt.hist(data=df, x='위도',bins=16)
for i, j in enumerate(g[0]):
    plt.text(g[1][i]+0.03, g[0][i]+1000, int(g[0][i]), fontsize=14)

# %% [markdown]
# ## 2)

# %%
plt.figure(figsize=(20,10))
g = plt.hist(data=df, x='경도',bins=16)
for i, j in enumerate(g[0]):
    plt.text(g[1][i]+0.03, g[0][i]+1000, int(g[0][i]), fontsize=14)

# %% [markdown]
# # 8.

# %% [markdown]
# ## 1)

# %%
df.corr()
# Out:
#           지번본번지     건물본번지        경도        위도
# 지번본번지  1.000000  0.048546  0.190310 -0.207301
# 건물본번지  0.048546  1.000000  0.004260  0.000766
# 경도     0.190310  0.004260  1.000000 -0.994441
# 위도    -0.207301  0.000766 -0.994441  1.000000

# %% [markdown]
# ## 2)

# %%
sns.heatmap(df.corr(),annot=True, cmap='Greens')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 9.

# %% [markdown]
# ## 1)

# %%
sns.scatterplot(data=df, x='경도', y='위도')
# Out:
# <AxesSubplot:xlabel='경도', ylabel='위도'>

# %% [markdown]
# ## 2)

# %%
sns.relplot(kind='scatter', data=df, x='경도', y='위도', hue='시도명', col='시도명')

# %% [markdown]
# ## 3)

# %%
sns.regplot(data=df, x='경도', y='위도')
# Out:
# <AxesSubplot:xlabel='경도', ylabel='위도'>

# %% [markdown]
# ## 4)

# %%
sns.lmplot(data=df, x='경도', y='위도',hue='시도명', col='시도명',col_wrap=2)

# %% [markdown]
# # 10.

# %%
g = df['상권업종대분류명'].value_counts().to_frame()
g
# Out:
#           상권업종대분류명
# 음식          176069
# 소매          134597
# 생활서비스        79356
# 학문/교육        29888
# 부동산          17263
# 관광/여가/오락      9490
# 숙박            3987
# 스포츠           1945

# %%
plt.figure(figsize=(20,10))
plt.bar(data=g, x=g.index, height=g.상권업종대분류명)
for i,j in enumerate(g.index):
    plt.text(j, g.상권업종대분류명[i], g.상권업종대분류명[i],fontsize=14, ha='center')

# %% [markdown]
# # 11.

# %% [markdown]
# ## 1)

# %%
df_food=df[df['상권업종대분류명']=='음식']
df_food.index=range(df_food.shape[0])
df_food.head()
# Out:
#          상호명 상권업종대분류명 상권업종중분류명   상권업종소분류명    시도명 시군구명         행정동명 법정동명 대지구분명  \
# 0        비지트       음식       한식  한식/백반/한정식  서울특별시  서초구         방배4동  방배동    대지
# 1       쓰리에프       음식       한식  한식/백반/한정식  서울특별시  동작구         사당2동  사당동    대지
# 2         채움       음식       한식  한식/백반/한정식  서울특별시  종로구  종로1.2.3.4가동  수송동    대지
# 3         다향       음식       한식  한식/백반/한정식  서울특별시  서초구         서초3동  서초동    대지
# 4  도전최강달인왕만두       음식       한식  한식/백반/한정식  서울특별시  강동구         고덕2동  고덕동    대지
#
#    지번본번지                  지번주소                 도로명  건물본번지  \
# 0    854  서울특별시 서초구 방배동 854-18    서울특별시 서초구 동광로18길     82
# 1    139  서울특별시 동작구 사당동 139-72  서울특별시 동작구 동작대로27가길     12
# 2     58      서울특별시 종로구 수송동 58       서울특별시 종로구 삼봉로     81
# 3   1485  서울특별시 서초구 서초동 1485-3       서울특별시 서초구 효령로    230
# 4    693     서울특별시 강동구 고덕동 693       서울특별시 강동구 고덕로    333
#
#                    도로명주소          경도         위도
# 0    서울특별시 서초구 동광로18길 82  126.991394  37.488375
# 1  서울특별시 동작구 동작대로27가길 12  126.980952  37.487105
# 2       서울특별시 종로구 삼봉로 81  126.981794  37.572387
# 3      서울특별시 서초구 효령로 230  127.009382  37.483436
# 4      서울특별시 강동구 고덕로 333  127.159471  37.556197

# %% [markdown]
# ## 2)

# %%
df_food[df_food['시군구명']=='강남구']['상권업종중분류명'].value_counts()
# Out:
# 한식         4135
# 커피점/카페     2434
# 양식         1326
# 일식/수산물     1012
# 유흥주점        938
# 분식          856
# 제과제빵떡케익     525
# 패스트푸드       511
# 닭/오리요리      367
# 중식          340
# 별식/퓨전요리     182
# 부페           50
# 기타음식업        37
# 음식배달서비스      10
# Name: 상권업종중분류명, dtype: int64

# %% [markdown]
# # 12

# %% [markdown]
# ## 1)

# %%
df_seoul_food=df_food[df_food['시도명']=='서울특별시']
df_seoul_food.index=range(df_seoul_food.shape[0])
df_seoul_food.head(5)
# Out:
#          상호명 상권업종대분류명 상권업종중분류명   상권업종소분류명    시도명 시군구명         행정동명 법정동명 대지구분명  \
# 0        비지트       음식       한식  한식/백반/한정식  서울특별시  서초구         방배4동  방배동    대지
# 1       쓰리에프       음식       한식  한식/백반/한정식  서울특별시  동작구         사당2동  사당동    대지
# 2         채움       음식       한식  한식/백반/한정식  서울특별시  종로구  종로1.2.3.4가동  수송동    대지
# 3         다향       음식       한식  한식/백반/한정식  서울특별시  서초구         서초3동  서초동    대지
# 4  도전최강달인왕만두       음식       한식  한식/백반/한정식  서울특별시  강동구         고덕2동  고덕동    대지
#
#    지번본번지                  지번주소                 도로명  건물본번지  \
# 0    854  서울특별시 서초구 방배동 854-18    서울특별시 서초구 동광로18길     82
# 1    139  서울특별시 동작구 사당동 139-72  서울특별시 동작구 동작대로27가길     12
# 2     58      서울특별시 종로구 수송동 58       서울특별시 종로구 삼봉로     81
# 3   1485  서울특별시 서초구 서초동 1485-3       서울특별시 서초구 효령로    230
# 4    693     서울특별시 강동구 고덕동 693       서울특별시 강동구 고덕로    333
#
#                    도로명주소          경도         위도
# 0    서울특별시 서초구 동광로18길 82  126.991394  37.488375
# 1  서울특별시 동작구 동작대로27가길 12  126.980952  37.487105
# 2       서울특별시 종로구 삼봉로 81  126.981794  37.572387
# 3      서울특별시 서초구 효령로 230  127.009382  37.483436
# 4      서울특별시 강동구 고덕로 333  127.159471  37.556197

# %% [markdown]
# ## 2)

# %%
food_gu=df_seoul_food.groupby(['시군구명','상권업종중분류명']).count()['지번주소'].to_frame()
food_gu
# Out:
#                지번주소
# 시군구명 상권업종중분류명
# 강남구  기타음식업       37
#      닭/오리요리     367
#      별식/퓨전요리    182
#      부페          50
#      분식         856
# ...             ...
# 중랑구  제과제빵떡케익    150
#      중식          74
#      커피점/카페     460
#      패스트푸드      122
#      한식        1346
#
# [349 rows x 1 columns]

# %% [markdown]
# ## 3)

# %%
food_gu.reset_index().groupby(['시군구명','상권업종중분류명'])['지번주소'].sum().unstack()
# Out:
# 상권업종중분류명  기타음식업  닭/오리요리  별식/퓨전요리    부페     분식      양식   유흥주점  음식배달서비스  일식/수산물  \
# 시군구명
# 강남구        37.0   367.0    182.0  50.0  856.0  1326.0  938.0     10.0  1012.0
# 강동구         5.0   264.0    105.0  29.0  488.0   169.0  587.0      3.0   369.0
# 강북구         4.0   185.0     66.0   7.0  317.0    73.0  431.0      2.0   179.0
# 강서구        15.0   298.0    104.0  21.0  529.0   376.0  719.0      2.0   457.0
# 관악구        13.0   302.0     91.0  13.0  547.0   323.0  761.0      3.0   351.0
# 광진구         7.0   238.0     78.0  13.0  451.0   241.0  484.0      1.0   339.0
# 구로구         7.0   272.0     96.0  21.0  435.0   113.0  676.0      4.0   252.0
# 금천구         9.0   173.0     83.0  13.0  298.0    83.0  396.0      1.0   192.0
# 노원구        11.0   296.0     75.0  12.0  423.0   137.0  431.0      6.0   232.0
# 도봉구         4.0   189.0     47.0  10.0  299.0    91.0  282.0      1.0   185.0
# 동대문구        8.0   209.0     84.0  14.0  402.0   130.0  509.0      4.0   232.0
# 동작구        13.0   179.0     64.0  11.0  353.0   129.0  347.0      2.0   253.0
# 마포구        23.0   227.0    112.0  19.0  444.0   431.0  779.0      3.0   445.0
# 서대문구       27.0   177.0     72.0   9.0  390.0   256.0  401.0      2.0   211.0
# 서초구        25.0   217.0    129.0  23.0  579.0   442.0  554.0      3.0   436.0
# 성동구        25.0   139.0     73.0   7.0  305.0   264.0  312.0      4.0   247.0
# 성북구        15.0   240.0     75.0   8.0  420.0   183.0  410.0      2.0   237.0
# 송파구        16.0   290.0    128.0  33.0  658.0   309.0  619.0      8.0   549.0
# 양천구        10.0   180.0     65.0  18.0  355.0    93.0  391.0      1.0   245.0
# 영등포구       18.0   233.0    125.0  50.0  524.0   277.0  788.0      3.0   421.0
# 용산구        12.0   122.0     79.0   7.0  306.0   630.0  447.0      7.0   255.0
# 은평구         5.0   246.0     77.0  15.0  440.0   140.0  561.0      NaN   290.0
# 종로구        18.0   157.0     87.0  16.0  428.0   513.0  364.0      3.0   268.0
# 중구         24.0   185.0     91.0  38.0  449.0   275.0  424.0      3.0   300.0
# 중랑구         5.0   209.0     81.0  10.0  373.0    83.0  520.0      1.0   222.0
#
# 상권업종중분류명  제과제빵떡케익     중식  커피점/카페  패스트푸드      한식
# 시군구명
# 강남구         525.0  340.0  2434.0  511.0  4135.0
# 강동구         245.0  112.0   795.0  238.0  1772.0
# 강북구         121.0   56.0   328.0  118.0  1402.0
# 강서구         263.0  168.0  1070.0  236.0  2135.0
# 관악구         183.0  142.0   750.0  203.0  1705.0
# 광진구         185.0  155.0   797.0  181.0  1399.0
# 구로구         154.0  256.0   633.0  176.0  1520.0
# 금천구         116.0  121.0   482.0  102.0  1126.0
# 노원구         204.0  110.0   622.0  223.0  1265.0
# 도봉구         122.0   62.0   383.0  104.0   911.0
# 동대문구        141.0  130.0   502.0  140.0  1632.0
# 동작구         177.0   78.0   556.0  143.0  1031.0
# 마포구         283.0  160.0  1449.0  214.0  3095.0
# 서대문구        184.0   99.0   747.0  173.0  1324.0
# 서초구         268.0  170.0  1324.0  258.0  2182.0
# 성동구         145.0  103.0   676.0  124.0  1493.0
# 성북구         201.0   95.0   669.0  197.0  1542.0
# 송파구         311.0  173.0  1092.0  311.0  2851.0
# 양천구         172.0   91.0   556.0  176.0  1112.0
# 영등포구        214.0  314.0  1087.0  202.0  2133.0
# 용산구         177.0  100.0   774.0  157.0  1510.0
# 은평구         211.0  115.0   612.0  156.0  1728.0
# 종로구         145.0  117.0  1111.0  150.0  1781.0
# 중구          207.0  127.0   923.0  183.0  1640.0
# 중랑구         150.0   74.0   460.0  122.0  1346.0

# %% [markdown]
# ## 4)

# %%
food_gu.reset_index().pivot_table(index='시군구명',columns='상권업종중분류명',values='지번주소')
# Out:
# 상권업종중분류명  기타음식업  닭/오리요리  별식/퓨전요리    부페     분식      양식   유흥주점  음식배달서비스  일식/수산물  \
# 시군구명
# 강남구        37.0   367.0    182.0  50.0  856.0  1326.0  938.0     10.0  1012.0
# 강동구         5.0   264.0    105.0  29.0  488.0   169.0  587.0      3.0   369.0
# 강북구         4.0   185.0     66.0   7.0  317.0    73.0  431.0      2.0   179.0
# 강서구        15.0   298.0    104.0  21.0  529.0   376.0  719.0      2.0   457.0
# 관악구        13.0   302.0     91.0  13.0  547.0   323.0  761.0      3.0   351.0
# 광진구         7.0   238.0     78.0  13.0  451.0   241.0  484.0      1.0   339.0
# 구로구         7.0   272.0     96.0  21.0  435.0   113.0  676.0      4.0   252.0
# 금천구         9.0   173.0     83.0  13.0  298.0    83.0  396.0      1.0   192.0
# 노원구        11.0   296.0     75.0  12.0  423.0   137.0  431.0      6.0   232.0
# 도봉구         4.0   189.0     47.0  10.0  299.0    91.0  282.0      1.0   185.0
# 동대문구        8.0   209.0     84.0  14.0  402.0   130.0  509.0      4.0   232.0
# 동작구        13.0   179.0     64.0  11.0  353.0   129.0  347.0      2.0   253.0
# 마포구        23.0   227.0    112.0  19.0  444.0   431.0  779.0      3.0   445.0
# 서대문구       27.0   177.0     72.0   9.0  390.0   256.0  401.0      2.0   211.0
# 서초구        25.0   217.0    129.0  23.0  579.0   442.0  554.0      3.0   436.0
# 성동구        25.0   139.0     73.0   7.0  305.0   264.0  312.0      4.0   247.0
# 성북구        15.0   240.0     75.0   8.0  420.0   183.0  410.0      2.0   237.0
# 송파구        16.0   290.0    128.0  33.0  658.0   309.0  619.0      8.0   549.0
# 양천구        10.0   180.0     65.0  18.0  355.0    93.0  391.0      1.0   245.0
# 영등포구       18.0   233.0    125.0  50.0  524.0   277.0  788.0      3.0   421.0
# 용산구        12.0   122.0     79.0   7.0  306.0   630.0  447.0      7.0   255.0
# 은평구         5.0   246.0     77.0  15.0  440.0   140.0  561.0      NaN   290.0
# 종로구        18.0   157.0     87.0  16.0  428.0   513.0  364.0      3.0   268.0
# 중구         24.0   185.0     91.0  38.0  449.0   275.0  424.0      3.0   300.0
# 중랑구         5.0   209.0     81.0  10.0  373.0    83.0  520.0      1.0   222.0
#
# 상권업종중분류명  제과제빵떡케익     중식  커피점/카페  패스트푸드      한식
# 시군구명
# 강남구         525.0  340.0  2434.0  511.0  4135.0
# 강동구         245.0  112.0   795.0  238.0  1772.0
# 강북구         121.0   56.0   328.0  118.0  1402.0
# 강서구         263.0  168.0  1070.0  236.0  2135.0
# 관악구         183.0  142.0   750.0  203.0  1705.0
# 광진구         185.0  155.0   797.0  181.0  1399.0
# 구로구         154.0  256.0   633.0  176.0  1520.0
# 금천구         116.0  121.0   482.0  102.0  1126.0
# 노원구         204.0  110.0   622.0  223.0  1265.0
# 도봉구         122.0   62.0   383.0  104.0   911.0
# 동대문구        141.0  130.0   502.0  140.0  1632.0
# 동작구         177.0   78.0   556.0  143.0  1031.0
# 마포구         283.0  160.0  1449.0  214.0  3095.0
# 서대문구        184.0   99.0   747.0  173.0  1324.0
# 서초구         268.0  170.0  1324.0  258.0  2182.0
# 성동구         145.0  103.0   676.0  124.0  1493.0
# 성북구         201.0   95.0   669.0  197.0  1542.0
# 송파구         311.0  173.0  1092.0  311.0  2851.0
# 양천구         172.0   91.0   556.0  176.0  1112.0
# 영등포구        214.0  314.0  1087.0  202.0  2133.0
# 용산구         177.0  100.0   774.0  157.0  1510.0
# 은평구         211.0  115.0   612.0  156.0  1728.0
# 종로구         145.0  117.0  1111.0  150.0  1781.0
# 중구          207.0  127.0   923.0  183.0  1640.0
# 중랑구         150.0   74.0   460.0  122.0  1346.0

# %% [markdown]
# ## 5)

# %%
a=food_gu.reset_index().groupby(['시군구명','상권업종중분류명'])['지번주소'].sum().unstack()
a.loc['강남구',:].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='상권업종중분류명'>

# %% [markdown]
# ## 6)

# %%
plt.figure(figsize=(20,15))
t=sns.barplot(x=a.index,y=a.sum(axis=1))
plt.title('구별 음식점 상호갯수')
plt.xlabel('시군구별')
plt.ylabel('상호수')
t.xtickle()
# Out:
# Text(0, 0.5, '상호수')

# %% [markdown]
# ## 7)

# %%
plt.figure(figsize=(20,15))
sns.barplot(x=a.columns,y=a.sum(axis=0))
plt.title('상권업종중분류별 음식점 상호갯수')
plt.xlabel('상권업종중분류별')
plt.ylabel('상호수')
# Out:
# Text(0, 0.5, '상호수')

# %% [markdown]
# ## 8)

# %%
g=a.reset_index().melt(id_vars='시군구명',value_name='개수')
g
# Out:
#     시군구명 상권업종중분류명      개수
# 0    강남구    기타음식업    37.0
# 1    강동구    기타음식업     5.0
# 2    강북구    기타음식업     4.0
# 3    강서구    기타음식업    15.0
# 4    관악구    기타음식업    13.0
# ..   ...      ...     ...
# 345  용산구       한식  1510.0
# 346  은평구       한식  1728.0
# 347  종로구       한식  1781.0
# 348   중구       한식  1640.0
# 349  중랑구       한식  1346.0
#
# [350 rows x 3 columns]

# %%
g1= sns.catplot(data=g, x='상권업종중분류명',y='개수', hue='시군구명', col='시군구명', col_wrap=2)
g1.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-460-55e1a4da0920> in <module>
#       1 g1= sns.catplot(data=g, x='상권업종중분류명',y='개수', hue='시군구명', col='시군구명', col_wrap=2)
# ----> 2 g1.xticks(rotation=90)
#
# AttributeError: 'FacetGrid' object has no attribute 'xticks'

# %% [markdown]
# ## 9)

# %%
sns.catplot(data=g, x='시군구명',y='개수', hue='상권업종중분류명', col='상권업종중분류명', col_wrap=2, kind='bar')
plt.xticks(rotation=90)

# %% [markdown]
# # 13
