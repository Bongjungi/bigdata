# %% [markdown]
# # 연습문제1

# %% [markdown]
# 1단계

# %%
import random
random.sample(range(10),10)
import seaborn as sns
iris= sns.load_dataset('iris')

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
for i in range(iris.shape[1]-1):
    iris.iloc[random.sample(range(len(iris)),20),i]=np.nan

# %%
import pandas as pd
pd.options.display.max_rows=151

# %%
iris.isna().sum()
# Out:
# sepal_length    20
# sepal_width     20
# petal_length    20
# petal_width     20
# species          0
# dtype: int64

# %% [markdown]
# 2단계

# %%
condition=iris.sepal_length.isna()|iris.sepal_width.isna()|iris.petal_length.isna()|iris.petal_width.isna()
iris[condition]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 3             NaN          3.1           1.5          0.2      setosa
# 11            4.8          3.4           1.6          NaN      setosa
# 12            NaN          3.0           1.4          0.1      setosa
# 19            NaN          3.8           1.5          0.3      setosa
# 20            5.4          3.4           NaN          0.2      setosa
# 21            5.1          NaN           1.5          0.4      setosa
# 25            NaN          3.0           1.6          0.2      setosa
# 26            NaN          3.4           1.6          0.4      setosa
# 27            5.2          3.5           NaN          NaN      setosa
# 28            5.2          NaN           NaN          0.2      setosa
# 29            4.7          NaN           1.6          0.2      setosa
# 30            4.8          3.1           1.6          NaN      setosa
# ...

# %% [markdown]
# 3단계

# %%
iris.fillna(value=iris.mean())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0        5.100000     3.500000      1.400000     0.200000      setosa
# 1        4.900000     3.000000      1.400000     0.200000      setosa
# 2        4.700000     3.200000      1.300000     0.200000      setosa
# 3        5.839231     3.100000      1.500000     0.200000      setosa
# 4        5.000000     3.600000      1.400000     0.200000      setosa
# 5        5.400000     3.900000      1.700000     0.400000      setosa
# 6        4.600000     3.400000      1.400000     0.300000      setosa
# 7        5.000000     3.400000      1.500000     0.200000      setosa
# 8        4.400000     2.900000      1.400000     0.200000      setosa
# 9        4.900000     3.100000      1.500000     0.100000      setosa
# 10       5.400000     3.700000      1.500000     0.200000      setosa
# 11       4.800000     3.400000      1.600000     1.161538      setosa
# ...

# %% [markdown]
# # 연습문제 - 실습형

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 1.

# %%
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# 2.

# %%
X=iris.loc[:,'sepal_length':'petal_width']
y=iris.loc[:,'species'].to_frame()

# %% [markdown]
# 3.

# %%
temp = iris.head(50)
temp
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %% [markdown]
# 4.

# %%
temp.info()
print(temp.shape)
temp.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  50 non-null     float64
#  1   sepal_width   50 non-null     float64
#  2   petal_length  50 non-null     float64
#  3   petal_width   50 non-null     float64
#  4   species       50 non-null     object
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB
# (50, 5)
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# ...

# %% [markdown]
# 5.

# %%
condition=iris.species=='versicolor'
iris_versicolor=iris[condition]
iris_versicolor
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %% [markdown]
# 6.

# %%
iris_df=pd.concat([X,y],axis=1)
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %% [markdown]
# 7.

# %%
X.apply(np.average)
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
iris.mean()
iris.iloc[:,:-1].apply(np.average, axis=0)
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %% [markdown]
# 8.

# %%
X.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(X.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 9.

# %%
X-X.apply(np.average)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0       -0.743333     0.442667        -2.358    -0.999333
# 1       -0.943333    -0.057333        -2.358    -0.999333
# 2       -1.143333     0.142667        -2.458    -0.999333
# 3       -1.243333     0.042667        -2.258    -0.999333
# 4       -0.843333     0.542667        -2.358    -0.999333
# 5       -0.443333     0.842667        -2.058    -0.799333
# 6       -1.243333     0.342667        -2.358    -0.899333
# 7       -0.843333     0.342667        -2.258    -0.999333
# 8       -1.443333    -0.157333        -2.358    -0.999333
# 9       -0.943333     0.042667        -2.258    -1.099333
# 10      -0.443333     0.642667        -2.258    -0.999333
# 11      -1.043333     0.342667        -2.158    -0.999333
# 12      -1.043333    -0.057333        -2.358    -1.099333
# 13      -1.543333    -0.057333        -2.658    -1.099333
# 14      -0.043333     0.942667        -2.558    -0.999333
# ...

# %% [markdown]
# 10.

# %%
iris.groupby(iris.species).mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %% [markdown]
# 11.

# %%
def fun(x):
    temp = x-iris.groupby(iris.species).mean().loc[x.species,:]
    temp.species=x.species
    return temp

# %%
iris.apply(fun,axis=1).groupby(iris.species).take(range(3))
# Out:
#                 petal_length  petal_width  sepal_length  sepal_width  \
# species
# setosa     0          -0.062       -0.046         0.094        0.072
#            1          -0.062       -0.046        -0.106       -0.428
#            2          -0.162       -0.046        -0.306       -0.228
# versicolor 50          0.440        0.074         1.064        0.430
#            51          0.240        0.174         0.464        0.430
#            52          0.640        0.174         0.964        0.330
# virginica  100         0.448        0.474        -0.288        0.326
#            101        -0.452       -0.126        -0.788       -0.274
#            102         0.348        0.074         0.512        0.026
#
#                    species
# species
# setosa     0        setosa
#            1        setosa
#            2        setosa
# versicolor 50   versicolor
#            51   versicolor
#            52   versicolor
# virginica  100   virginica
#            101   virginica
# ...
