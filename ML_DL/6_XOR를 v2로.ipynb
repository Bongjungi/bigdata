# %% [markdown]
# ## 1. XOR

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt
import pandas as pd

# %%
# 1. dataset

x_data = [[0,0],[0,1],[1,0],[1,1]]
y_data = [[0],[1],[1],[0]]

# 2. 모델 구성

model = Sequential()
model.add(Dense(units=10, input_dim=2, activation='relu'))
model.add(Dense(units=20, activation='relu'))
model.add(Dense(units=10, activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))
print(model.summary())

# 3. 모델 학습과정

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])

# 4. 학습

hist = model.fit(x_data, y_data, epochs=100, verbose=2)

# 5. 학습과정 보기 및 평가

hist.history.keys()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 10)                30
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                220
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# ...
# Total params: 471
# Trainable params: 471
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 - 0s - loss: 0.6825 - binary_accuracy: 0.7500
# Epoch 2/100
# 1/1 - 0s - loss: 0.6808 - binary_accuracy: 0.5000
# Epoch 3/100
# 1/1 - 0s - loss: 0.6789 - binary_accuracy: 0.5000
# Epoch 4/100
# ...

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy'])

# %%
fig, loss_ax = plt.subplots(figsize=(10,5))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
acc_ax=loss_ax.twinx() #loss_ax와 x축을 공유하는 acc_ax생성
acc_ax.plot(hist.history['binary_accuracy'],'g',label='b accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('b accuracy')
loss_ax.legend('upper left')
acc_ax.legend('lower left')
plt.show()

# %%
# 입력값을 받아 (0 0 / 0 1 / 1 0 / 1 1)
while True:
    input_list = input('space로 분리해서 0이나 1을 2개 입력(종료:9)').strip().split()
    input_data = list(map(int, input_list))
    if input_data[0]==9:
        break;
    input_data = np.array(input_data).reshape(-1,2)
    print('입력값 : ', input_data)
    print('예측값 : ', int(model.predict(input_data).round()))
# Out:
# space로 분리해서 0이나 1을 2개 입력(종료:9)0 0
# 입력값 :  [[0 0]]
# 예측값 :  0
# space로 분리해서 0이나 1을 2개 입력(종료:9)9

# %% [markdown]
# ## 2. AND

# %%
# 1. dataset

x_data = [[0,0],[0,1],[1,0],[1,1]]
y_data = [[0],[0],[0],[1]]

# 2. 모델 구성

model = Sequential()
model.add(Dense(units=1, input_dim=2, activation='sigmoid'))

print(model.summary())

# 3. 모델 학습과정

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])

# 4. 학습

hist = model.fit(x_data, y_data, epochs=1000, verbose=2)

# 5. 학습과정 보기 및 평가

hist.history.keys()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 1)                 3
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# 1/1 - 0s - loss: 0.7691 - binary_accuracy: 0.7500
# Epoch 2/1000
# 1/1 - 0s - loss: 0.7687 - binary_accuracy: 0.7500
# Epoch 3/1000
# 1/1 - 0s - loss: 0.7683 - binary_accuracy: 0.7500
# Epoch 4/1000
# 1/1 - 0s - loss: 0.7679 - binary_accuracy: 0.7500
# Epoch 5/1000
# 1/1 - 0s - loss: 0.7675 - binary_accuracy: 0.7500
# Epoch 6/1000
# 1/1 - 0s - loss: 0.7670 - binary_accuracy: 0.7500
# Epoch 7/1000
# 1/1 - 0s - loss: 0.7666 - binary_accuracy: 0.7500
# Epoch 8/1000
# 1/1 - 0s - loss: 0.7662 - binary_accuracy: 0.7500
# Epoch 9/1000
# 1/1 - 0s - loss: 0.7658 - binary_accuracy: 0.7500
# Epoch 10/1000
# ...

# %%
fig, loss_ax = plt.subplots(figsize=(10,5))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
acc_ax=loss_ax.twinx() #loss_ax와 x축을 공유하는 acc_ax생성
acc_ax.plot(hist.history['binary_accuracy'],'g',label='b accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('b accuracy')
loss_ax.legend('upper left')
acc_ax.legend('lower left')
plt.show()

# %%
# 입력값을 받아 (0 0 / 0 1 / 1 0 / 1 1)
while True:
    input_list = input('space로 분리해서 0이나 1을 2개 입력(종료:9)').strip().split()
    input_data = list(map(int, input_list))
    if input_data[0]==9:
        break;
    input_data = np.array(input_data).reshape(-1,2)
    print('입력값 : ', input_data)
    print('예측값 : ', int(model.predict(input_data).round()))
# Out:
# space로 분리해서 0이나 1을 2개 입력(종료:9)0 1
# 입력값 :  [[0 1]]
# 예측값 :  0
# space로 분리해서 0이나 1을 2개 입력(종료:9)1 1
# 입력값 :  [[1 1]]
# 예측값 :  1
# space로 분리해서 0이나 1을 2개 입력(종료:9)0 0
# 입력값 :  [[0 0]]
# 예측값 :  0
# space로 분리해서 0이나 1을 2개 입력(종료:9)9

# %% [markdown]
# ## 3. OR

# %%
# 1. dataset

x_data = [[0,0],[0,1],[1,0],[1,1]]
y_data = [[0],[1],[1],[1]]

# 2. 모델 구성

model = Sequential()
model.add(Dense(units=1, input_dim=2, activation='sigmoid'))

print(model.summary())

# 3. 모델 학습과정

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])

# 4. 학습

hist = model.fit(x_data, y_data, epochs=1000, verbose=2)

# 5. 학습과정 보기 및 평가

hist.history.keys()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_7 (Dense)              (None, 1)                 3
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# 1/1 - 0s - loss: 0.4419 - binary_accuracy: 1.0000
# Epoch 2/1000
# 1/1 - 0s - loss: 0.4415 - binary_accuracy: 0.7500
# Epoch 3/1000
# 1/1 - 0s - loss: 0.4412 - binary_accuracy: 0.7500
# Epoch 4/1000
# 1/1 - 0s - loss: 0.4408 - binary_accuracy: 0.7500
# Epoch 5/1000
# 1/1 - 0s - loss: 0.4404 - binary_accuracy: 0.7500
# Epoch 6/1000
# 1/1 - 0s - loss: 0.4401 - binary_accuracy: 0.7500
# Epoch 7/1000
# 1/1 - 0s - loss: 0.4397 - binary_accuracy: 0.7500
# Epoch 8/1000
# 1/1 - 0s - loss: 0.4394 - binary_accuracy: 0.7500
# Epoch 9/1000
# 1/1 - 0s - loss: 0.4390 - binary_accuracy: 0.7500
# Epoch 10/1000
# ...

# %%
fig, loss_ax = plt.subplots(figsize=(10,5))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
acc_ax=loss_ax.twinx() #loss_ax와 x축을 공유하는 acc_ax생성
acc_ax.plot(hist.history['binary_accuracy'],'g',label='b accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('b accuracy')
loss_ax.legend('upper left')
acc_ax.legend('lower left')
plt.show()

# %%
# 입력값을 받아 (0 0 / 0 1 / 1 0 / 1 1)
while True:
    input_list = input('space로 분리해서 0이나 1을 2개 입력(종료:9)').strip().split()
    input_data = list(map(int, input_list))
    if input_data[0]==9:
        break;
    input_data = np.array(input_data).reshape(-1,2)
    print('입력값 : ', input_data)
    print('예측값 : ', int(model.predict(input_data).round()))
# Out:
# space로 분리해서 0이나 1을 2개 입력(종료:9)0 0
# 입력값 :  [[0 0]]
# 예측값 :  0
# space로 분리해서 0이나 1을 2개 입력(종료:9)0 1
# 입력값 :  [[0 1]]
# 예측값 :  1
# space로 분리해서 0이나 1을 2개 입력(종료:9)1 1
# 입력값 :  [[1 1]]
# 예측값 :  1
# space로 분리해서 0이나 1을 2개 입력(종료:9)9

# %%
x_data = [[1],[2],[5],[8],[10]]
y_data = [[5],[15],[68],[80],[95]]
from sklearn.preprocessing import StandardScaler
scaler_x = StandardScaler()
scaler_x.fit(x_data)
x_data = scaler_x.transform(x_data)

#x_data=StandardScaler().fit_transform(x_data) 안 좋음 뒷 부분에서 활용 못함
scaler_y = StandardScaler()
scaler_y.fit(y_data)
y_data = scaler_y.transform(y_data)

model = Sequential()
model.add(Dense(units=1, input_dim=1, activation='relu'))

print(model.summary())

# 3. 모델 학습과정

model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# 4. 학습

hist = model.fit(x_data, y_data, epochs=1000, verbose=2)

# 5. 학습과정 보기 및 평가

hist.history.keys()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_14 (Dense)             (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# 1/1 - 0s - loss: 0.7398 - mae: 0.7781
# Epoch 2/1000
# 1/1 - 0s - loss: 0.7388 - mae: 0.7773
# Epoch 3/1000
# 1/1 - 0s - loss: 0.7379 - mae: 0.7764
# Epoch 4/1000
# 1/1 - 0s - loss: 0.7369 - mae: 0.7756
# Epoch 5/1000
# 1/1 - 0s - loss: 0.7360 - mae: 0.7748
# Epoch 6/1000
# 1/1 - 0s - loss: 0.7350 - mae: 0.7739
# Epoch 7/1000
# 1/1 - 0s - loss: 0.7341 - mae: 0.7731
# Epoch 8/1000
# 1/1 - 0s - loss: 0.7331 - mae: 0.7722
# Epoch 9/1000
# 1/1 - 0s - loss: 0.7322 - mae: 0.7714
# Epoch 10/1000
# 1/1 - 0s - loss: 0.7313 - mae: 0.7705
# Epoch 11/1000
# 1/1 - 0s - loss: 0.7303 - mae: 0.7697
# Epoch 12/1000
# ...

# %%
#이렇게 하면 안됨
x_data = [[1],[2],[5],[8],[10]]
y_data = [[5],[15],[68],[80],[95]]


model = Sequential()
model.add(Dense(units=1, input_dim=1, activation='relu'))

print(model.summary())

# 3. 모델 학습과정

model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# 4. 학습

hist = model.fit(x_data, y_data, epochs=1000, verbose=2)

# 5. 학습과정 보기 및 평가

hist.history.keys()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_9 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# 1/1 - 0s - loss: 2909.0483 - mae: 44.3390
# Epoch 2/1000
# 1/1 - 0s - loss: 2908.2971 - mae: 44.3328
# Epoch 3/1000
# 1/1 - 0s - loss: 2907.5459 - mae: 44.3266
# Epoch 4/1000
# 1/1 - 0s - loss: 2906.7947 - mae: 44.3204
# Epoch 5/1000
# 1/1 - 0s - loss: 2906.0432 - mae: 44.3142
# Epoch 6/1000
# 1/1 - 0s - loss: 2905.2925 - mae: 44.3080
# Epoch 7/1000
# 1/1 - 0s - loss: 2904.5417 - mae: 44.3018
# Epoch 8/1000
# 1/1 - 0s - loss: 2903.7913 - mae: 44.2956
# Epoch 9/1000
# 1/1 - 0s - loss: 2903.0405 - mae: 44.2894
# Epoch 10/1000
# 1/1 - 0s - loss: 2902.2900 - mae: 44.2832
# Epoch 11/1000
# ...

# %%
fig, loss_ax = plt.subplots(figsize=(10,5))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
acc_ax=loss_ax.twinx() #loss_ax와 x축을 공유하는 acc_ax생성
acc_ax.plot(hist.history['mae'],'g',label='b accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('mae')
loss_ax.legend('upper left')
acc_ax.legend('lower left')
plt.show()

# %%
while True:
    num = int(input('숫자 입력'))
    if num==9:
        break;
    scaled_num = scaler_x.transform([[num]])
    print('입력값 : ', num)
    print('예측값 : ', scaler_y.inverse_transform(model.predict(scaled_num)))
# Out:
# 숫자 입력5
# 입력값 :  5
# 예측값 :  [[52.6]]
# 숫자 입력9
