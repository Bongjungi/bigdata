# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import warnings
warnings.filterwarnings(action='ignore')
import numpy as np
plt.rc('font', family='Malgun Gothic') 
plt.rc('axes', unicode_minus=False)
import matplotlib.font_manager as fm
font_path = 'C:\Windows\Fonts\HMFMPYUN.TTF'
font_prop = fm.FontProperties(fname=font_path, size=20)
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU, Dropout, Embedding, SimpleRNN, Flatten, Conv1D, MaxPooling1D
from tensorflow.keras import models
import seaborn as sns
import tensorflow.keras.utils as utils
from tensorflow.keras.callbacks import Callback

# %%
g1=pd.read_csv('data/권선사거리20162017.csv', encoding='cp949')
g2=pd.read_csv('data/권선사거리20182020.csv', encoding='cp949')
n1=pd.read_csv('data/나혜석거리20162017.csv', encoding='cp949')
n2=pd.read_csv('data/나혜석거리20182020.csv', encoding='cp949')
i1=pd.read_csv('data/인계사거리20162017.csv', encoding='cp949')
i2=pd.read_csv('data/인계사거리20182020.csv', encoding='cp949')

# %%
data=pd.concat([g1,g2,n1,n2,i1,i2])

# %%
data
# Out:
#                 사고번호               사고일시   요일              시군구  사고내용  사망자수  \
# 0   2016011600100485   2016년 1월 16일 19시  토요일  경기도 수원시 권선구 권선동  경상사고     0
# 1   2016012800100383   2016년 1월 28일 16시  목요일  경기도 수원시 권선구 권선동  경상사고     0
# 2   2016021300100278   2016년 2월 13일 16시  토요일  경기도 수원시 권선구 권선동  경상사고     0
# 3   2016021500100497   2016년 2월 15일 20시  월요일  경기도 수원시 권선구 권선동  중상사고     0
# 4   2016021900100051   2016년 2월 19일 03시  금요일  경기도 수원시 권선구 권선동  경상사고     0
# ..               ...                ...  ...              ...   ...   ...
# 88  2020112300100324  2020년 11월 23일 14시  월요일  경기도 수원시 팔달구 인계동  중상사고     0
# 89  2020120200100185   2020년 12월 2일 12시  수요일  경기도 수원시 팔달구 인계동  경상사고     0
# 90  2020122200100507  2020년 12월 22일 20시  화요일  경기도 수원시 팔달구 인계동  경상사고     0
# 91  2020122300100322  2020년 12월 23일 16시  수요일  경기도 수원시 팔달구 인계동  경상사고     0
# 92  2020123000100335  2020년 12월 30일 17시  수요일  경기도 수원시 팔달구 인계동  중상사고     0
#
#     중상자수  경상자수  부상신고자수          사고유형  ... 기상상태         도로형태 가해운전자 차종 가해운전자 성별  \
# ...
